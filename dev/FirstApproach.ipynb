# %% [markdown]
# # Table Extraction Case Study
# ### AAIC Self Case Study II
# ### Author: Soumya De
#
# <hr>
#
# ## 1. Data Collection & Preprocessing
#
# * Dataset - marmot_dataset_v1.0
# * Source - https://www.icst.pku.edu.cn/cpdp/docs/20190424190300041510.zip
#
# We have downloaded the dataset from the above URL as a zip folder and extracted it. Now we will look into the extracted directory to understand how the dataset is organized.

# %%
# importing dependencies
import os
import numpy as np
import cv2
import matplotlib.pyplot as plt
import struct
from xml.dom import minidom
from xml.etree import ElementTree as eltree
import pandas as pd
from tqdm import tqdm
from shutil import copyfile
from PIL import Image, ImageDraw
import tensorflow as tf
from tensorflow.keras import Model
from tensorflow.keras.layers import Input, Dense, Conv2D, Activation, Dropout, Layer, UpSampling2D, Conv2DTranspose, Concatenate
from tensorflow.keras.applications import VGG19
import pytesseract

# %%
data_dir = os.path.join('data', 'marmot_dataset_v1.0')
os.listdir(data_dir)
# Out:
# ['copyright.txt',
#  'data',
#  'Layout Description Schema for Marmot.pdf',
#  'xml_schema']

# %% [markdown]
# * The main folder contains some files describing the dataset and a data directory that actually holds the data.

# %%
data_dir = os.path.join(data_dir, 'data')
os.listdir(data_dir)
# Out:
# ['Chinese', 'English']

# %% [markdown]
# * Marmot dataset is composed of Chinese and English pages, which is kept is separate folders. Lets have a look into each of these.

# %%
print(os.listdir(os.path.join(data_dir, 'Chinese')))
print(os.listdir(os.path.join(data_dir, 'English')))
# Out:
# ['Negative', 'Positive']
# ['Negative', 'Positive']

# %% [markdown]
# * Okay, both of these folders have same subdirectory structure, consisting folders named positive and negative.
# * For the sake of simplicity, we will consider only the English folder now and explore it further.
# * Later on, we can check what's inside the chinese directory.

# %%
# exploring the english subdirectory
english_data_dir = os.path.join(data_dir, 'English')
print('Contents of the English subdirectory : ')
print(os.listdir(english_data_dir))
print()
print('Contents of the positive subdirectory : ')
print(os.listdir(os.path.join(english_data_dir, 'positive')))
print()
print('Contents of the negative subdirectory : ')
print(os.listdir(os.path.join(english_data_dir, 'negative')))
# Out:
# Contents of the English subdirectory :
# ['Negative', 'Positive']
#
# Contents of the positive subdirectory :
# ['Labeled', 'Raw']
#
# Contents of the negative subdirectory :
# ['Labeled', 'Raw']

# %% [markdown]
# * We can see that the positive and negative directories have also similar contents
# * There are two folders namely Labeled and Raw, in both positive and negative directories.

# %% [markdown]
# #### * Positive

# %%
print("Number of files in Positive/Raw : ", len(os.listdir(os.path.join(english_data_dir, 'Positive', 'Raw'))))
print()
print("Some contents of the Positive/Raw directory :")
os.listdir(os.path.join(english_data_dir, 'Positive', 'Raw'))[:10]
# Out:
# Number of files in Positive/Raw :  1018
#
# Some contents of the Positive/Raw directory :
# ['10.1.1.1.2006_3.bmp',
#  '10.1.1.1.2006_3_phy.xml',
#  '10.1.1.1.2010_5.bmp',
#  '10.1.1.1.2010_5_phy.xml',
#  '10.1.1.1.2013_63.bmp',
#  '10.1.1.1.2013_63_phy.xml',
#  '10.1.1.1.2013_64.bmp',
#  '10.1.1.1.2013_64_phy.xml',
#  '10.1.1.1.2014_4.bmp',
#  '10.1.1.1.2014_4_phy.xml']

# %%
bmp_files = [f for f in os.listdir(os.path.join(english_data_dir, 'Positive', 'Raw')) if f.endswith('bmp')]
xml_raw_files = [f for f in os.listdir(os.path.join(english_data_dir, 'Positive', 'Raw')) if f.endswith('xml')]
print("Number of .bmp files (Positive): ", len(bmp_files))
print("Number of raw .xml files (Positive) : ", len(xml_raw_files))
# Out:
# Number of .bmp files (Positive):  509
# Number of raw .xml files (Positive) :  509

# %%
print("Number of files in Positive/Labeled : ", len(os.listdir(os.path.join(english_data_dir, 'Positive', 'Labeled'))))
print()
print("Some contents of the Positive/Labeled directory :")
os.listdir(os.path.join(english_data_dir, 'Positive', 'Labeled'))[:10]
# Out:
# Number of files in Positive/Labeled :  509
#
# Some contents of the Positive/Labeled directory :
# ['10.1.1.1.2006_3.xml',
#  '10.1.1.1.2010_5.xml',
#  '10.1.1.1.2013_63.xml',
#  '10.1.1.1.2013_64.xml',
#  '10.1.1.1.2014_4.xml',
#  '10.1.1.1.2014_6.xml',
#  '10.1.1.1.2018_4.xml',
#  '10.1.1.1.2018_8.xml',
#  '10.1.1.1.2019_2.xml',
#  '10.1.1.1.2019_3.xml']

# %%
# checking a random positive .bmp file

r = np.random.randint(len(bmp_files))

img_filepath = os.path.join(english_data_dir, 'Positive', 'Raw', bmp_files[r])
img = cv2.imread(img_filepath, cv2.IMREAD_UNCHANGED)
plt.figure(figsize=(20,10))
plt.axis('off')
plt.title(bmp_files[r])
plt.imshow(img)
plt.show()

# %%
# checking the corresponding .xml annotation
# Ref: https://stackabuse.com/reading-and-writing-xml-files-in-python/
# Ref: https://stackoverflow.com/questions/52824584/do-anyone-know-how-to-extract-image-coordinate-from-marmot-dataset

def hex2double(hexcode):
    """
    This function takes a 16 digit hexadecimal representation and
    convert it into its equivalent floating point form
    """
    return struct.unpack('!d', bytes.fromhex(hexcode))[0]

xml_fpath = img_filepath.replace('Raw', 'Labeled').replace('bmp', 'xml')
xml_file = eltree.parse(xml_fpath)
root = xml_file.getroot()
left, bottom, right, top = (hex2double(i) for i in root.get('CropBox').split())
pa_width = np.abs(left - right)
pa_height = np.abs(top - bottom)

bounding_boxes = []

height, width, _ = img.shape


for each_table_comp in xml_file.findall(".//Composite[@Label='Table']"):
    t_left, t_bottom, t_right, t_top = [hex2double(i) for i in each_table_comp.get('BBox').split()]
    
    t_left = width/pa_width * np.abs(t_left - left) 
    t_right = width/pa_width * np.abs(t_right - left)
    t_bottom = height/pa_height * np.abs(t_bottom - bottom) 
    t_top = height/pa_height * np.abs(t_top - bottom)
    bounding_boxes.append([t_left, t_top, t_right, t_bottom])

# %%
def crop_table(image_path, list_of_bboxes):
    fig = plt.figure(figsize=(20,10))
    image = cv2.imread(image_path, cv2.IMREAD_UNCHANGED)
    i = 1
    for each_bbox in list_of_bboxes:
        ax = fig.add_subplot(len(list_of_bboxes), 1, i)
        left, top, right, bottom = (int(i) for i in each_bbox)
        table_image = image[bottom:top, left:right]
        plt.axis('off')
        plt.imshow(table_image)
        i = i+1
    return None

# %%
crop_table(img_filepath, bounding_boxes)

# %% [markdown]
# * Therefore, with help of above code snippet we can fetch the bounding boxes for all all the tables in an given image, in the marmot_dataset_v1.0
# * There is another version of this dataset available, annotated by the TableNet team (Paliwal et al.), that  gives the column level bounding boxes.
#
# Source : https://drive.google.com/drive/folders/1QZiv5RKe3xlOBdTzuTVuYRxixemVIODp
#
# We have downloaded the dataset from the above URL (zip folder) and extracted it. Take a look at the data.

# %%
data_dir = os.path.join('data', 'marmot_extended')
print("Total number of files in the directory : ", len(os.listdir(data_dir)))
print("Few contents of the directory : ")
os.listdir(data_dir)[0:5]
# Out:
# Total number of files in the directory :  1004
# Few contents of the directory :
# ['10.1.1.1.2006_3.bmp',
#  '10.1.1.1.2006_3.xml',
#  '10.1.1.1.2010_5.bmp',
#  '10.1.1.1.2013_63.bmp',
#  '10.1.1.1.2013_63.xml']

# %%
bmp_files = [i for i in os.listdir(data_dir) if i.endswith('bmp')]
xml_files = [i for i in os.listdir(data_dir) if i.endswith('xml')]
print("Number of .bmp files : ", len(bmp_files))
print("Number of .xml files : ", len(xml_files))
# Out:
# Number of .bmp files :  509
# Number of .xml files :  495

# %% [markdown]
# * These annotations contains the bounding box for each columns of the tables.
# * This dataset only contains the images from the English/Positive subfolder of the original dataset.
# * The number of annotation files is 495 whereas there are 509 bitmap images. Hence 14 xml files of corresponding images are not present.
# * We have seen a typical image data in the marmot dataset before, lets check only the layout the new annotation files

# %%
# random .xml file in the marmot_extended
r = np.random.randint(len(xml_files))

xml_file_path = os.path.join(data_dir, xml_files[r])
xml_file = eltree.parse(xml_file_path)

# %%
# trying to retrive image dimension
rt = xml_file.getroot()
int(rt.findall('size')[0].findall('width')[0].text), int(rt.findall('size')[0].findall('height')[0].text)
# Out:
# (794, 1123)

# %%
# checking the name of annotated objects
for ele in rt.findall('object'):
    print(ele.find('name').text)
# Out:
# column
# column
# column
# column
# column

# %% [markdown]
# * These new annotations only consists of bounding boxes for each column present in the image.
# * The annotations in marmot_dataset_v1.0 contains only table annotations
# * We will use these two type of annotations and create mask w.r.t. each image present in the dataset.
# * Since the column level annotations are missing for 14 datapoints, we will also ignone the 14 table level annotations

# %%
# This function will take a list of file names (images) and create table mask and column mask for each file and store the image paths and dimension in a dataframe

def hex2double(hexcode):
    """
    Input: 16digit hexadecimal number
    Output: Equivalent floating point representation
    """
    return struct.unpack('!d', bytes.fromhex(hexcode))[0]


def return_bboxes_extended(xml):
    """
    Input: Annotated xml file of an image from the marmot extended dataset
    Output: Dimension of the image and the list of bounding boxes of table columns present in the image
    """
    xml_file = eltree.parse(xml)
    root = xml_file.getroot()
    bboxes = []
    width = int(rt.findall('size')[0].findall('width')[0].text)
    height = int(rt.findall('size')[0].findall('height')[0].text)
    for ele in root.findall('object'):
        if ele.find('name').text == 'column':
            bbox = ele.find('bndbox')
            left = int(bbox.find('xmin').text)
            right = int(bbox.find('xmax').text)
            top = int(bbox.find('ymin').text)
            bottom = int(bbox.find('ymax').text)
        bboxes.append([left, top, right, bottom])
    return width, height, bboxes


def return_bboxes_v1(xml, width, height):
    """
    Input: Annotated xml file of an image from the marmot v1.0 dataset
    Output: The list of bounding boxes of tables present in the image
    """
    xml_file = eltree.parse(xml)
    root = xml_file.getroot()
    left, bottom, right, top = (hex2double(i) for i in root.get('CropBox').split())
    pa_width = np.abs(left - right)
    pa_height = np.abs(top - bottom)
    bboxes = []
    for each_table_comp in xml_file.findall(".//Composite[@Label='Table']"):
        t_left, t_bottom, t_right, t_top = [hex2double(i) for i in each_table_comp.get('BBox').split()]
        t_left = int(width/pa_width * np.abs(t_left - left))
        t_right = int(width/pa_width * np.abs(t_right - left))
        t_bottom = int(height/pa_height * np.abs(t_bottom - bottom)) 
        t_top = int(height/pa_height * np.abs(t_top - bottom))
        bboxes.append([t_left, t_top, t_right, t_bottom])
    return bboxes


def create_mask(img_path, list_of_bboxes, dim, mode='table'):
    """
    Input: Image, its corresponding list of bounding boxes, dimension of the image 
    and mode specifying the annotation type (table/column)
    Output: Create corresponding mask image (containing the boxes) and return the mask file path
    """
    data_dir = os.path.join('data', 'marmot_masked')
    image_dir = os.path.join(data_dir, 'images')
    mask_dir = os.path.join(data_dir, 'masks', mode)
    if not os.path.exists(data_dir):
        os.makedirs(data_dir)
    if not os.path.exists(image_dir):
        os.makedirs(image_dir)
    if not os.path.exists(mask_dir):
        os.makedirs(mask_dir)
    fname = img_path.split(os.path.sep)[-1].replace('bmp', 'png')
    dest = os.path.join(image_dir, fname)
    if mode == 'table':
        img = Image.open(img_path)
        img.save(dest, 'png')
    image = Image.new("RGB", dim)
    mask = ImageDraw.Draw(image)
    for each_list in list_of_bboxes:
        mask.rectangle(each_list, fill=255)
    mask_fn = os.path.join(mask_dir, fname)
    image = np.array(image)
    image = Image.fromarray(image[:,:,0])
    image.save(mask_fn)
    if mode == 'table':
        return dest, mask_fn  
    return mask_fn


def compute_masks():
    """
    Returns a pandas dataframe containing the imagepath and mask_path and dimension.
    It invokes the above two methods to create corresponding mask images
    """
    images_dir = os.path.join('data', 'marmot_extended')
    img_file_list = [i for i in os.listdir(images_dir) if i.endswith('bmp')]
    img_df = pd.DataFrame(columns=['image_path', 'image_dim', 'tablemask_path', 'columnmask_path'])
    for each_image in tqdm(img_file_list):
        img_path = os.path.join(images_dir, each_image)
        table_annot = os.path.join('data', 'marmot_dataset_v1.0', 'data', 'English', 'Positive', 'Labeled', each_image.replace('bmp', 'xml'))
        column_annot = img_path.replace('bmp', 'xml')
        if not os.path.exists(column_annot):
            continue
        width, height, column_bboxes = return_bboxes_extended(column_annot)
        dim = (width, height)
        table_bboxes = return_bboxes_v1(table_annot, width, height)
        image_path, table_mask_path = create_mask(img_path, table_bboxes, dim, mode='table')
        column_mask_path = create_mask(img_path, column_bboxes, dim, mode='column')
        img_df.loc[len(img_df.index)] = [image_path, dim, table_mask_path, column_mask_path]
        csv_fname = os.path.join('data', 'marmot_masked', 'data.csv')
        img_df.to_csv(csv_fname, index=False)
    return img_df

# %%
img_df = compute_masks()
# Out:
# 100%|██████████| 509/509 [00:49<00:00, 10.18it/s]

# %% [markdown]
# * We created the table and column mask w.r.t. each image
# * We will now analyze the distribution of widths and heights

# %%
width_list = [i[0] for i in img_df['image_dim'].values]
height_list = [i[1] for i in img_df['image_dim'].values]

plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
plt.hist(width_list)
plt.title('width dist. of images')
plt.subplot(1,2,2)
plt.hist(height_list)
plt.title('height dist. of images')
plt.show()

# %% [markdown]
# * All images in the dataset are of width and height i.e., (816, 1056)
# * There are only 494 images with table and column level bounding box annotations
# * We will now check another similar dataset ICDAR 2017
#
#
# <hr>
#
# * Dataset - ICDAR 2017
# * Source - https://github.com/mawanda-jun/TableTrainNet/tree/master/dataset

# %%
data_dir = os.path.join('data', 'ICDAR 2017')
os.listdir(data_dir)
# Out:
# ['Annotations', 'data.csv', 'Images', 'other', 'table_images', 'table_masks']

# %%
print('Number of images : ', len(os.listdir(os.path.join(data_dir, 'Images'))))
print('Number of annotation files : ', len(os.listdir(os.path.join(data_dir, 'Annotations'))))
# Out:
# Number of images :  1600
# Number of annotation files :  1600

# %% [markdown]
# * There are total 1600 images and annotations in the ICDAR 2017 dataset.
# * We now look at a random image and annotation from it.

# %%
bmp_files = os.listdir(os.path.join(data_dir, 'Images'))

r = np.random.randint(len(bmp_files))

img_filepath = os.path.join(data_dir, 'Images', bmp_files[r])
img = cv2.imread(img_filepath, cv2.IMREAD_UNCHANGED)
plt.figure(figsize=(20,10))
plt.axis('off')
plt.title(bmp_files[r])
plt.imshow(img)
plt.show()

# %% [markdown]
# * All the images in the dataset doesn't mandatorily contains a table since dataset was designed for recognition for various objects like formula, figure etc. along with table

# %%
xml_files = os.listdir(os.path.join(data_dir, 'Annotations'))

xml_file_path = os.path.join(data_dir, 'Annotations', xml_files[r])
xml_file = minidom.parse(xml_file_path)
print(xml_file.toprettyxml())
# Out:
# <?xml version="1.0" ?>
# <document filename="POD_1442.xml">
#
#
# 	<tableRegion>
#
#
# 		<Coords points="152,250 903,250 152,1115 903,1115"/>
#
#
# 	</tableRegion>
#
#
# </document>

# %% [markdown]
# * But we can check if a table is present in an image and get its bounding box from the corresponding annotation file. The annotation files contain tags called <tableRegion> with bounding box information if a table is present in the corresponding image.
#
# * Therefore, we will consider the images with tables only and  create masked images for those images in the dataset as we have done in the previous section for the marmot data.

# %%
def create_mask(img_path, list_of_bboxes, dim):
    """
    Input: takes a image path and list of bounding boxes to create corresponding mask image
    for ICDAR 2017 data
    Output: returns the file name of the mask file
    """
    data_dir = os.path.join('data', 'ICDAR 2017')
    image_dir = os.path.join(data_dir, 'table_images')
    mask_dir = os.path.join(data_dir, 'table_masks')
    if not os.path.exists(data_dir):
        os.makedirs(data_dir)
    if not os.path.exists(image_dir):
        os.makedirs(image_dir)
    if not os.path.exists(mask_dir):
        os.makedirs(mask_dir)
    fname = img_path.split(os.path.sep)[-1].replace('bmp', 'png')
    dest = os.path.join(image_dir, fname)
    img = Image.open(img_path)
    img.save(dest, 'png')
    image = Image.new("RGB", dim)
    mask = ImageDraw.Draw(image)
    for each_list in list_of_bboxes:
        mask.rectangle(each_list, fill=255)
    mask_fn = os.path.join(mask_dir, fname)
    image = np.array(image)
    image = Image.fromarray(image[:,:,0])
    image.save(mask_fn) 
    return mask_fn


def compute_masks():
    """
    Returns a pandas dataframe containing the imagepath and mask_path and dimension.
    It invokes the above method to create corresponding mask images
    """
    img_df = pd.DataFrame(columns=['image_path', 'image_dim', 'mask_path'])
    images_dir = os.path.join('data', 'ICDAR 2017', 'Images')
    annots_dir = os.path.join('data', 'ICDAR 2017', 'Annotations')
    xml_filelist = os.listdir(annots_dir)
    for each_xml in tqdm(xml_filelist):
        xml_path = os.path.join(annots_dir, each_xml)
        xml = eltree.parse(xml_path)
        root = xml.getroot()
        table_list = root.findall('tableRegion')
        if len(table_list)==0:
            continue
        else:
            vertex_list = []
            for each_table in table_list:
                cord_list = each_table.find('Coords').get('points')
                cord_list = cord_list.split()
                vertices = [tuple(int(i) for i in cord_list[0].split(',')), tuple(int(i) for i in cord_list[-1].split(','))]
                vertex_list.append(vertices)
            image_path = xml_path.replace('Annotations', 'Images').replace('xml', 'bmp')
            image = cv2.imread(image_path, cv2.IMREAD_UNCHANGED)
            height, width, _ = image.shape
            mask_path = create_mask(image_path, vertex_list, (width, height))

            img_df.loc[len(img_df.index)] = [image_path, (width, height), mask_path]
        csv_fname = os.path.join('data', 'ICDAR 2017', 'data.csv')
    img_df.to_csv(csv_fname, index=False)
    return img_df

# %%
img_df = compute_masks()
# Out:
# 100%|██████████| 1600/1600 [01:46<00:00, 15.01it/s]

# %% [markdown]
# * We created the table mask w.r.t. the images containing table
# * We will now analyze the distribution of widths and heights and how many images in the dataset contains tables

# %%
print('Number of datapoints in ICDAR-2017 table extraction dataset : ', len(img_df))
# Out:
# Number of datapoints in ICDAR-2017 table extraction dataset :  549

# %%
width_list = [i[0] for i in img_df['image_dim'].values]
height_list = [i[1] for i in img_df['image_dim'].values]

plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
plt.hist(width_list)
plt.title('width dist. of images')
plt.subplot(1,2,2)
plt.hist(height_list)
plt.title('height dist. of images')
plt.show()

# %% [markdown]
# * The dimension of the images in this dataset vary from 800 to 1400 in width and 1000 to 1400 in height
# * But dimension of most of the images are (1000, 1300)
#
# ### Discussions
#
# * We have seen two datasets for the task for table extraction. They are marmot and ICDAR 2017
# * The ICDAR 2017 contains annotations table level bounding boxes whereas Marmot has both table and column level annotations
# * There are 495 datapoints available in Marmot and 549 in ICDAR 2017
# * The dimension of an image in Marmot is (816, 1056)
# * The dimension of a typical image ICDAR 2017 is (1000, 1300)
# * We have converted the annotations of marmot_v1.0 into masked images of tables and used the marmot_extended to create column level masks
# * The transformed masks and their corresponding images are stored in a new folder along with a csv to keep track of the individuals image and their masks.
# * We done a similar task in case of ICDAR dataset i.e., converting mask and storing them in a new location along with a csv
# * Inspired from the TableNet paper we will use the marmot data to train. Since it has both table & column level mask, it will help to learn the structural form of a table better.
# * Once the we have obtained a trained model, we will use the ICDAR data to test our model performance.
#
#
# <hr>
#
# ## 2. Modeling
#
# In this section we will experiment with the TableNet architechture proposed by Paliwaal et. al. First we will create a tensorflow dataset object using the marmot data and then we define the actual model.
#
# ### * Data definition

# %%
# defining data directory
tr_data_dir = os.path.join('data', 'marmot_masked')
train_df = pd.read_csv(os.path.join(tr_data_dir, 'data.csv'))

# %%
tf.keras.backend.clear_session()
dataset = tf.data.Dataset.from_tensor_slices((train_df['image_path'].values, train_df['tablemask_path'].values, train_df['columnmask_path'].values))

# %%
# defining function for loading the images into memory
# it will also perform resizing and normalizing at the time of loading 
def _parse_function(image, mask, colmask):
    dim = (512,512)
    image_decoded = tf.io.decode_png(tf.io.read_file(image), channels=3)
    image = tf.cast(image_decoded, tf.float32)
    image = tf.image.resize(image, dim)
    image = tf.cast(image, tf.float32) / 255.0
    
    mask_decoded = tf.io.decode_png(tf.io.read_file(mask), channels=1)
    mask = tf.cast(mask_decoded, tf.float32)
    mask = tf.image.resize(mask, dim)
    mask = tf.cast(mask, tf.float32) / 255.0

    colmask_decoded = tf.io.decode_png(tf.io.read_file(colmask), channels=1)
    colmask = tf.cast(colmask_decoded, tf.float32)
    colmask = tf.image.resize(colmask, dim)
    colmask = tf.cast(colmask, tf.float32) / 255.0
    
    mask_dict = {'table': mask, 'column': colmask}

    return image, mask_dict

# %%
DATA_SIZE = len(dataset)
VAL_SIZE = 0.1

VAL_LENGTH = int(VAL_SIZE*DATA_SIZE)
TRAIN_LENGTH = int((1-VAL_SIZE) * DATA_SIZE)

BATCH_SIZE = 1
BUFFER_SIZE = TRAIN_LENGTH

VAL_BUFFER_SIZE = VAL_LENGTH

VALIDATION_STEPS = VAL_LENGTH // BATCH_SIZE

STEPS_PER_EPOCH = TRAIN_LENGTH // BATCH_SIZE

# %%
train = dataset.take(TRAIN_LENGTH)
val = dataset.skip(TRAIN_LENGTH)
train = train.map(_parse_function)
val = val.map(_parse_function)

# %%
train_dataset = train.shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
val_dataset = val.shuffle(VAL_BUFFER_SIZE).batch(BATCH_SIZE)

# %% [markdown]
# Lets check how a typical datapoint looks like

# %%
# function to display a list of images
def visualize(image_list):
  plt.figure(figsize=(15, 15))
  title = ['Input Image', 'Table Mask', 'Column Mask']
  for i in range(len(image_list)):
    plt.subplot(1, len(image_list), i+1)
    plt.title(title[i])
    plt.imshow(tf.keras.preprocessing.image.array_to_img(image_list[i]))
    plt.axis('off')
  plt.show()

# %%
for image, mask  in train.take(1):
  # print(mask.shape)
  visualize([image, mask['table'], mask['column']])

# %% [markdown]
# ### * Model definition

# %%
class TableConvLayer(Layer):
    def __init__(self, name='table'):
        super().__init__(name=name)
        self.conv7 = Conv2D(512, (1,1), activation='relu', name='conv7table')
        self.upsample_conv7 = UpSampling2D((2,2))
        self.concat_p4 = Concatenate()
        self.upsample_p4 = UpSampling2D((2,2))

        self.concat_p3 = Concatenate()
        self.upsample_p3 = UpSampling2D((2,2))

        self.upsample_p3_2 = UpSampling2D((2,2))
        self.convtranspose = Conv2DTranspose(3, (3,3), strides=2, padding='same')

    def call(self, inputs):
        X, pool3, pool4 = inputs
        X = self.conv7(X)
        X = self.upsample_conv7(X)
        X = self.concat_p4([X, pool4])
        X = self.upsample_p4(X)
        X = self.concat_p3([X, pool3])
        X = self.upsample_p3(X)
        X = self.upsample_p3_2(X)
        X = self.convtranspose(X)

        return X


class ColumnConvLayer(Layer):
    def __init__(self, name='column'):
        super().__init__(name=name)
        self.conv7 = Conv2D(512, (1,1), activation='relu', name='conv7column')
        self.dropout = Dropout(0.8)
        self.conv8 = Conv2D(512, (1,1), activation='relu', name='conv8column')
        self.upsample_conv8 = UpSampling2D((2,2))
        self.concat_p4 = Concatenate()
        self.upsample_p4 = UpSampling2D((2,2))

        self.concat_p3 = Concatenate()
        self.upsample_p3 = UpSampling2D((2,2))

        self.upsample_p3_2 = UpSampling2D((2,2))
        self.convtranspose = Conv2DTranspose(3, (3,3), strides=2, padding='same')

    def call(self, inputs):
        X, pool3, pool4 = inputs
        X = self.conv7(X)
        X = self.dropout(X)
        X = self.conv8(X)
        X = self.upsample_conv8(X)
        X = self.concat_p4([X, pool4])
        X = self.upsample_p4(X)
        X = self.concat_p3([X, pool3])
        X = self.upsample_p3(X)
        X = self.upsample_p3_2(X)
        X = self.convtranspose(X)

        return X

# %%
def build_tablenet():
    tf.keras.backend.clear_session()
    input_shape = (512,512,3)

    base = VGG19(input_shape=input_shape, include_top=False, weights='imagenet')

    end_layers_list = ['block3_pool', 'block4_pool', 'block5_pool']
    end_layers = [base.get_layer(i).output for i in end_layers_list]

    X = Conv2D(512, (1,1), activation='relu', name='block6_conv1')(end_layers[-1])
    X = Dropout(0.8)(X)
    X = Conv2D(512, (1,1), activation='relu', name='block6_conv2')(X)
    X = Dropout(0.8)(X)
    
    table_branch = TableConvLayer()([X, end_layers[0], end_layers[1]])
    column_branch = ColumnConvLayer()([X, end_layers[0], end_layers[1]])

    model = Model(inputs=base.input, outputs=[table_branch, column_branch], name='TableNetVGG19')
    return model

# %%
model = build_tablenet()
tf.keras.utils.plot_model(model,show_shapes=True,show_layer_names=True)

# %%
model.summary()
# Out:
# Model: "TableNetVGG19"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 512, 512, 3) 0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 512, 512, 64) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 512, 512, 64) 36928       block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling2D)      (None, 256, 256, 64) 0           block1_conv2[0][0]
# __________________________________________________________________________________________________
# block2_conv1 (Conv2D)           (None, 256, 256, 128 73856       block1_pool[0][0]
# __________________________________________________________________________________________________
# block2_conv2 (Conv2D)           (None, 256, 256, 128 147584      block2_conv1[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 128, 128, 128 0           block2_conv2[0][0]
# __________________________________________________________________________________________________
# block3_conv1 (Conv2D)           (None, 128, 128, 256 295168      block2_pool[0][0]
# __________________________________________________________________________________________________
# block3_conv2 (Conv2D)           (None, 128, 128, 256 590080      block3_conv1[0][0]
# __________________________________________________________________________________________________
# block3_conv3 (Conv2D)           (None, 128, 128, 256 590080      block3_conv2[0][0]
# __________________________________________________________________________________________________
# block3_conv4 (Conv2D)           (None, 128, 128, 256 590080      block3_conv3[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 64, 64, 256)  0           block3_conv4[0][0]
# __________________________________________________________________________________________________
# block4_conv1 (Conv2D)           (None, 64, 64, 512)  1180160     block3_pool[0][0]
# __________________________________________________________________________________________________
# block4_conv2 (Conv2D)           (None, 64, 64, 512)  2359808     block4_conv1[0][0]
# __________________________________________________________________________________________________
# block4_conv3 (Conv2D)           (None, 64, 64, 512)  2359808     block4_conv2[0][0]
# __________________________________________________________________________________________________
# block4_conv4 (Conv2D)           (None, 64, 64, 512)  2359808     block4_conv3[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 32, 32, 512)  0           block4_conv4[0][0]
# __________________________________________________________________________________________________
# block5_conv1 (Conv2D)           (None, 32, 32, 512)  2359808     block4_pool[0][0]
# __________________________________________________________________________________________________
# block5_conv2 (Conv2D)           (None, 32, 32, 512)  2359808     block5_conv1[0][0]
# __________________________________________________________________________________________________
# block5_conv3 (Conv2D)           (None, 32, 32, 512)  2359808     block5_conv2[0][0]
# __________________________________________________________________________________________________
# block5_conv4 (Conv2D)           (None, 32, 32, 512)  2359808     block5_conv3[0][0]
# __________________________________________________________________________________________________
# block5_pool (MaxPooling2D)      (None, 16, 16, 512)  0           block5_conv4[0][0]
# __________________________________________________________________________________________________
# block6_conv1 (Conv2D)           (None, 16, 16, 512)  262656      block5_pool[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 16, 16, 512)  0           block6_conv1[0][0]
# __________________________________________________________________________________________________
# block6_conv2 (Conv2D)           (None, 16, 16, 512)  262656      dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 16, 16, 512)  0           block6_conv2[0][0]
# __________________________________________________________________________________________________
# table (TableConvLayer)          (None, 512, 512, 3)  297219      dropout_1[0][0]
#                                                                  block3_pool[0][0]
#                                                                  block4_pool[0][0]
# __________________________________________________________________________________________________
# column (ColumnConvLayer)        (None, 512, 512, 3)  559875      dropout_1[0][0]
#                                                                  block3_pool[0][0]
#                                                                  block4_pool[0][0]
# ==================================================================================================
# Total params: 21,406,790
# Trainable params: 21,406,790
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ### * Callback definition and model compilation

# %%
# Ref: https://www.pyimagesearch.com/2018/06/04/keras-multiple-outputs-and-multiple-losses/


losses = {
    "table": tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    "column": tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
}

lossWeights = {"table": 1.0, "column": 1.0}
optim = tf.keras.optimizers.Adam(learning_rate=0.0001, epsilon=1e-08)
sc_acc = tf.keras.metrics.SparseCategoricalAccuracy(name='sc_accuracy')


model.compile(optimizer = optim,
              loss = losses,
              metrics = [sc_acc],
              loss_weights = lossWeights)

# %%
# visualizing initial predictions (without training)
def render(mask):
  mask = tf.argmax(mask, axis=-1)
  mask = mask[..., tf.newaxis]
  return mask[0]

# %%
for image, masks in val_dataset.take(1):
    table_mask, column_mask = masks['table'], masks['column']

pred_tab_mask, pred_col_mask = model.predict(image)
visualize([image[0], render(pred_tab_mask), render(pred_col_mask)])

# %%
# defining model callbacks (checkpoint and tensorboard)
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint, ReduceLROnPlateau

checkpoint_path = "tablenet_weights/cp_{epoch:04d}_{val_loss:.4f}.ckpt" 
checkpoint_dir = os.path.dirname(checkpoint_path)

log_dir = "tablenet_logs"

if not os.path.exists(checkpoint_dir):
  os.makedirs(checkpoint_dir)
if not os.path.exists(log_dir):
  os.makedirs(log_dir)

cp_callback = ModelCheckpoint(checkpoint_path, verbose=1, save_best_only=True, monitor='val_loss', save_weights_only=True)

tb_callback = TensorBoard(log_dir)


callbacks = [cp_callback, tb_callback]

# %% [markdown]
# ### * Model training

# %%
model.fit(
    train_dataset, epochs=200,
    steps_per_epoch= STEPS_PER_EPOCH,
    validation_data=val_dataset,
    validation_steps= VALIDATION_STEPS,
    callbacks=callbacks
)
# Out:
#  0.2484 - val_table_sc_accuracy: 0.9407 - val_column_sc_accuracy: 0.9302
#
# Epoch 00147: val_loss did not improve from 0.36941
# Epoch 148/200
# 444/444 [==============================] - 133s 291ms/step - loss: 0.0486 - table_loss: 0.0163 - column_loss: 0.0323 - table_sc_accuracy: 0.9907 - column_sc_accuracy: 0.9819 - val_loss: 0.6297 - val_table_loss: 0.3844 - val_column_loss: 0.2452 - val_table_sc_accuracy: 0.9413 - val_column_sc_accuracy: 0.9332
#
# Epoch 00148: val_loss did not improve from 0.36941
# Epoch 149/200
# 444/444 [==============================] - 134s 292ms/step - loss: 0.0492 - table_loss: 0.0166 - column_loss: 0.0326 - table_sc_accuracy: 0.9906 - column_sc_accuracy: 0.9820 - val_loss: 0.6161 - val_table_loss: 0.3817 - val_column_loss: 0.2344 - val_table_sc_accuracy: 0.9398 - val_column_sc_accuracy: 0.9329
#
# Epoch 00149: val_loss did not improve from 0.36941
# Epoch 150/200
# 444/444 [==============================] - 134s 292ms/step - loss: 0.0498 - table_loss: 0.0174 - column_loss: 0.0323 - table_sc_accuracy: 0.9904 - column_sc_accuracy: 0.9821 - val_loss: 0.6215 - val_table_loss: 0.3758 - val_column_loss: 0.2457 - val_table_sc_accuracy: 0.9428 - val_column_sc_accuracy: 0.9318
#
# Epoch 00150: val_loss did not improve from 0.36941
# Epoch 151/200
# 444/444 [==============================] - 134s 292ms/step - loss: 0.0497 - table_loss: 0.0169 - column_loss: 0.0328 - table_sc_accuracy: 0.9905 - column_sc_accuracy: 0.9818 - val_loss: 0.5973 - val_table_loss: 0.3576 - val_column_loss: 0.2398 - val_table_sc_accuracy: 0.9419 - val_column_sc_accuracy: 0.9318
#
# Epoch 00151: val_loss did not improve from 0.36941
# Epoch 152/200
# 444/444 [==============================] - 133s 291ms/step - loss: 0.0457 - table_loss: 0.0157 - column_loss: 0.0301 - table_sc_accuracy: 0.9911 - column_sc_accuracy: 0.9834 - val_loss: 0.6002 - val_table_loss: 0.3662 - val_column_loss: 0.2340 - val_table_sc_accuracy: 0.9414 - val_column_sc_accuracy: 0.9319
#
# Epoch 00152: val_loss did not improve from 0.36941
# Epoch 153/200
# 444/444 [==============================] - 134s 291ms/step - loss: 0.0479 - table_loss: 0.0155 - column_loss: 0.0324 - table_sc_accuracy: 0.9913 - column_sc_accuracy: 0.9824 - val_loss: 0.6291 - val_table_loss: 0.3800 - val_column_loss: 0.2492 - val_table_sc_accuracy: 0.9417 - val_column_sc_accuracy: 0.9334
#
# Epoch 00153: val_loss did not improve from 0.36941
# Epoch 154/200
# 444/444 [==============================] - 133s 291ms/step - loss: 0.0483 - table_loss: 0.0165 - column_loss: 0.0318 - table_sc_accuracy: 0.9907 - column_sc_accuracy: 0.9825 - val_loss: 0.5557 - val_table_loss: 0.3173 - val_column_loss: 0.2385 - val_table_sc_accuracy: 0.9392 - val_column_sc_accuracy: 0.9300
#
# Epoch 00154: val_loss did not improve from 0.36941
# Epoch 155/200
# 444/444 [==============================] - 133s 291ms/step - loss: 0.0530 - table_loss: 0.0196 - column_loss: 0.0334 - table_sc_accuracy: 0.9896 - column_sc_accuracy: 0.9819 - val_loss: 0.5576 - val_table_loss: 0.3321 - val_column_loss: 0.2254 - val_table_sc_accuracy: 0.9380 - val_column_sc_accuracy: 0.9295
#
# Epoch 00155: val_loss did not improve from 0.36941
# Epoch 156/200
# 444/444 [==============================] - 133s 291ms/step - loss: 0.2194 - table_loss: 0.1223 - column_loss: 0.0971 - table_sc_accuracy: 0.9680 - column_sc_accuracy: 0.9641 - val_loss: 0.4470 - val_table_loss: 0.2531 - val_column_loss: 0.1938 - val_table_sc_accuracy: 0.9420 - val_column_sc_accuracy: 0.9310
#
# Epoch 00156: val_loss did not improve from 0.36941
# Epoch 157/200
# 444/444 [==============================] - 134s 292ms/step - loss: 0.0624 - table_loss: 0.0234 - column_loss: 0.0391 - table_sc_accuracy: 0.9887 - column_sc_accuracy: 0.9798 - val_loss: 0.5658 - val_table_loss: 0.3307 - val_column_loss: 0.2350 - val_table_sc_accuracy: 0.9418 - val_column_sc_accuracy: 0.9313
#
# Epoch 00157: val_loss did not improve from 0.36941
# Epoch 158/200
# 444/444 [==============================] - 133s 291ms/step - loss: 0.0524 - table_loss: 0.0186 - column_loss: 0.0338 - table_sc_accuracy: 0.9902 - column_sc_accuracy: 0.9816 - val_loss: 0.5809 - val_table_loss: 0.3397 - val_column_loss: 0.2412 - val_table_sc_accuracy: 0.9438 - val_column_sc_accuracy: 0.9316
#
# Epoch 00158: val_loss did not improve from 0.36941
# Epoch 159/200
# 444/444 [==============================] - 133s 291ms/step - loss: 0.0451 - table_loss: 0.0164 - column_loss: 0.0287 - table_sc_accuracy: 0.9911 - column_sc_accuracy: 0.9839 - val_loss: 0.6327 - val_table_loss: 0.3726 - val_column_loss: 0.2602 - val_table_sc_accuracy: 0.9422 - val_column_sc_accuracy: 0.9316
#
# Epoch 00159: val_loss did not improve from 0.36941
# Epoch 160/200
# 444/444 [==============================] - 133s 291ms/step - loss: 0.0453 - table_loss: 0.0156 - column_loss: 0.0298 - table_sc_accuracy: 0.9911 - column_sc_accuracy: 0.9831 - val_loss: 0.6457 - val_table_loss: 0.3785 - val_column_loss: 0.2672 - val_table_sc_accuracy: 0.9435 - val_column_sc_accuracy: 0.9320
#
# Epoch 00160: val_loss did not improve from 0.36941
# Epoch 161/200
# 444/444 [==============================] - 133s 291ms/step - loss: 0.0428 - table_loss: 0.0149 - column_loss: 0.0279 - table_sc_accuracy: 0.9914 - column_sc_accuracy: 0.9839 - val_loss: 0.6460 - val_table_loss: 0.3779 - val_column_loss: 0.2681 - val_table_sc_accuracy: 0.9430 - val_column_sc_accuracy: 0.9307
#
# Epoch 00161: val_loss did not improve from 0.36941
# Epoch 162/200
# 444/444 [==============================] - 134s 291ms/step - loss: 0.0429 - table_loss: 0.0148 - column_loss: 0.0280 - table_sc_accuracy: 0.9914 - column_sc_accuracy: 0.9838 - val_loss: 0.6547 - val_table_loss: 0.3848 - val_column_loss: 0.2698 - val_table_sc_accuracy: 0.9428 - val_column_sc_accuracy: 0.9303
#
# Epoch 00162: val_loss did not improve from 0.36941
# Epoch 163/200
# 444/444 [==============================] - 133s 291ms/step - loss: 0.0460 - table_loss: 0.0158 - column_loss: 0.0302 - table_sc_accuracy: 0.9909 - column_sc_accuracy: 0.9828 - val_loss: 0.6558 - val_table_loss: 0.3941 - val_column_loss: 0.2617 - val_table_sc_accuracy: 0.9424 - val_column_sc_accuracy: 0.9316
#
# Epoch 00163: val_loss did not improve from 0.36941
# Epoch 164/200
# 444/444 [==============================] - 133s 291ms/step - loss: 0.0474 - table_loss: 0.0165 - column_loss: 0.0309 - table_sc_accuracy: 0.9905 - column_sc_accuracy: 0.9824 - val_loss: 0.6297 - val_table_loss: 0.3755 - val_column_loss: 0.2542 - val_table_sc_accuracy: 0.9400 - val_column_sc_accuracy: 0.9310
#
# Epoch 00164: val_loss did not improve from 0.36941
# Epoch 165/200
# 444/444 [==============================] - 133s 291ms/step - loss: 0.0449 - table_loss: 0.0158 - column_loss: 0.0291 - table_sc_accuracy: 0.9911 - column_sc_accuracy: 0.9837 - val_loss: 0.6447 - val_table_loss: 0.3926 - val_column_loss: 0.2521 - val_table_sc_accuracy: 0.9425 - val_column_sc_accuracy: 0.9316
#
# Epoch 00165: val_loss did not improve from 0.36941
# Epoch 166/200
# 444/444 [==============================] - 133s 291ms/step - loss: 0.0461 - table_loss: 0.0159 - column_loss: 0.0302 - table_sc_accuracy: 0.9909 - column_sc_accuracy: 0.9830 - val_loss: 0.6280 - val_table_loss: 0.3794 - val_column_loss: 0.2486 - val_table_sc_accuracy: 0.9411 - val_column_sc_accuracy: 0.9325
#
# Epoch 00166: val_loss did not improve from 0.36941
# Epoch 167/200
# 444/444 [==============================] - 133s 291ms/step - loss: 0.0504 - table_loss: 0.0178 - column_loss: 0.0326 - table_sc_accuracy: 0.9905 - column_sc_accuracy: 0.9821 - val_loss: 0.6521 - val_table_loss: 0.3963 - val_column_loss: 0.2558 - val_table_sc_accuracy: 0.9420 - val_column_sc_accuracy: 0.9316
#
# Epoch 00167: val_loss did not improve from 0.36941
# Epoch 168/200
# 444/444 [==============================] - 133s 291ms/step - loss: 0.0424 - table_loss: 0.0146 - column_loss: 0.0278 - table_sc_accuracy: 0.9918 - column_sc_accuracy: 0.9844 - val_loss: 0.6338 - val_table_loss: 0.3914 - val_column_loss: 0.2424 - val_table_sc_accuracy: 0.9427 - val_column_sc_accuracy: 0.9319
#
# Epoch 00168: val_loss did not improve from 0.36941
# Epoch 169/200
# 444/444 [==============================] - 133s 291ms/step - loss: 0.0462 - table_loss: 0.0163 - column_loss: 0.0299 - table_sc_accuracy: 0.9908 - column_sc_accuracy: 0.9829 - val_loss: 0.5081 - val_table_loss: 0.2687 - val_column_loss: 0.2395 - val_table_sc_accuracy: 0.9521 - val_column_sc_accuracy: 0.9347
#
# Epoch 00169: val_loss did not improve from 0.36941
# Epoch 170/200
# 444/444 [==============================] - 133s 291ms/step - loss: 0.1039 - table_loss: 0.0488 - column_loss: 0.0551 - table_sc_accuracy: 0.9814 - column_sc_accuracy: 0.9741 - val_loss: 0.4536 - val_table_loss: 0.2607 - val_column_loss: 0.1929 - val_table_sc_accuracy: 0.9421 - val_column_sc_accuracy: 0.9290
#
# Epoch 00170: val_loss did not improve from 0.36941
# Epoch 171/200
# 444/444 [==============================] - 133s 291ms/step - loss: 0.0711 - table_loss: 0.0270 - column_loss: 0.0441 - table_sc_accuracy: 0.9878 - column_sc_accuracy: 0.9786 - val_loss: 0.5082 - val_table_loss: 0.2871 - val_column_loss: 0.2210 - val_table_sc_accuracy: 0.9421 - val_column_sc_accuracy: 0.9295
#
# Epoch 00171: val_loss did not improve from 0.36941
# Epoch 172/200
# 444/444 [==============================] - 133s 291ms/step - loss: 0.0497 - table_loss: 0.0170 - column_loss: 0.0327 - table_sc_accuracy: 0.9911 - column_sc_accuracy: 0.9823 - val_loss: 0.5840 - val_table_loss: 0.3478 - val_column_loss: 0.2362 - val_table_sc_accuracy: 0.9432 - val_column_sc_accuracy: 0.9321
#
# Epoch 00172: val_loss did not improve from 0.36941
# Epoch 173/200
# 444/444 [==============================] - 133s 291ms/step - loss: 0.0461 - table_loss: 0.0158 - column_loss: 0.0303 - table_sc_accuracy: 0.9912 - column_sc_accuracy: 0.9829 - val_loss: 0.6268 - val_table_loss: 0.3760 - val_column_loss: 0.2508 - val_table_sc_accuracy: 0.9431 - val_column_sc_accuracy: 0.9316
#
# Epoch 00173: val_loss did not improve from 0.36941
# Epoch 174/200
# 444/444 [==============================] - 133s 291ms/step - loss: 0.0444 - table_loss: 0.0161 - column_loss: 0.0283 - table_sc_accuracy: 0.9908 - column_sc_accuracy: 0.9838 - val_loss: 0.6479 - val_table_loss: 0.3915 - val_column_loss: 0.2564 - val_table_sc_accuracy: 0.9437 - val_column_sc_accuracy: 0.9333
#
# Epoch 00174: val_loss did not improve from 0.36941
# Epoch 175/200
# 444/444 [==============================] - 133s 291ms/step - loss: 0.0443 - table_loss: 0.0155 - column_loss: 0.0288 - table_sc_accuracy: 0.9911 - column_sc_accuracy: 0.9833 - val_loss: 0.6763 - val_table_loss: 0.3980 - val_column_loss: 0.2783 - val_table_sc_accuracy: 0.9435 - val_column_sc_accuracy: 0.9315
#
# Epoch 00175: val_loss did not improve from 0.36941
# Epoch 176/200
# 444/444 [==============================] - 133s 291ms/step - loss: 0.0422 - table_loss: 0.0148 - column_loss: 0.0274 - table_sc_accuracy: 0.9914 - column_sc_accuracy: 0.9839 - val_loss: 0.6232 - val_table_loss: 0.3631 - val_column_loss: 0.2601 - val_table_sc_accuracy: 0.9459 - val_column_sc_accuracy: 0.9344
#
# Epoch 00176: val_loss did not improve from 0.36941
# Epoch 177/200
# 444/444 [==============================] - 134s 291ms/step - loss: 0.0482 - table_loss: 0.0178 - column_loss: 0.0303 - table_sc_accuracy: 0.9903 - column_sc_accuracy: 0.9826 - val_loss: 0.6489 - val_table_loss: 0.3776 - val_column_loss: 0.2713 - val_table_sc_accuracy: 0.9434 - val_column_sc_accuracy: 0.9322
#
# Epoch 00177: val_loss did not improve from 0.36941
# Epoch 178/200
# 444/444 [==============================] - 133s 291ms/step - loss: 0.0466 - table_loss: 0.0160 - column_loss: 0.0305 - table_sc_accuracy: 0.9909 - column_sc_accuracy: 0.9823 - val_loss: 0.6252 - val_table_loss: 0.3664 - val_column_loss: 0.2588 - val_table_sc_accuracy: 0.9444 - val_column_sc_accuracy: 0.9311
#
# Epoch 00178: val_loss did not improve from 0.36941
# Epoch 179/200
# 444/444 [==============================] - 133s 291ms/step - loss: 0.0446 - table_loss: 0.0157 - column_loss: 0.0289 - table_sc_accuracy: 0.9909 - column_sc_accuracy: 0.9833 - val_loss: 0.6322 - val_table_loss: 0.3748 - val_column_loss: 0.2573 - val_table_sc_accuracy: 0.9434 - val_column_sc_accuracy: 0.9315
#
# Epoch 00179: val_loss did not improve from 0.36941
# Epoch 180/200
# 444/444 [==============================] - 133s 291ms/step - loss: 0.0482 - table_loss: 0.0166 - column_loss: 0.0316 - table_sc_accuracy: 0.9906 - column_sc_accuracy: 0.9819 - val_loss: 0.6640 - val_table_loss: 0.4006 - val_column_loss: 0.2634 - val_table_sc_accuracy: 0.9426 - val_column_sc_accuracy: 0.9333
#
# Epoch 00180: val_loss did not improve from 0.36941
# Epoch 181/200
# 444/444 [==============================] - 133s 291ms/step - loss: 0.0482 - table_loss: 0.0170 - column_loss: 0.0312 - table_sc_accuracy: 0.9902 - column_sc_accuracy: 0.9821 - val_loss: 0.6297 - val_table_loss: 0.3810 - val_column_loss: 0.2486 - val_table_sc_accuracy: 0.9436 - val_column_sc_accuracy: 0.9330
#
# Epoch 00181: val_loss did not improve from 0.36941
# Epoch 182/200
# 444/444 [==============================] - 133s 291ms/step - loss: 0.0450 - table_loss: 0.0158 - column_loss: 0.0292 - table_sc_accuracy: 0.9909 - column_sc_accuracy: 0.9832 - val_loss: 0.6266 - val_table_loss: 0.3757 - val_column_loss: 0.2508 - val_table_sc_accuracy: 0.9435 - val_column_sc_accuracy: 0.9319
#
# Epoch 00182: val_loss did not improve from 0.36941
# Epoch 183/200
# 444/444 [==============================] - 133s 291ms/step - loss: 0.0923 - table_loss: 0.0428 - column_loss: 0.0496 - table_sc_accuracy: 0.9835 - column_sc_accuracy: 0.9765 - val_loss: 0.4528 - val_table_loss: 0.2657 - val_column_loss: 0.1871 - val_table_sc_accuracy: 0.9365 - val_column_sc_accuracy: 0.9289
#
# Epoch 00183: val_loss did not improve from 0.36941
# Epoch 184/200
# 444/444 [==============================] - 133s 291ms/step - loss: 0.0705 - table_loss: 0.0252 - column_loss: 0.0453 - table_sc_accuracy: 0.9881 - column_sc_accuracy: 0.9773 - val_loss: 0.5413 - val_table_loss: 0.3215 - val_column_loss: 0.2198 - val_table_sc_accuracy: 0.9437 - val_column_sc_accuracy: 0.9328
#
# Epoch 00184: val_loss did not improve from 0.36941
# Epoch 185/200
# 444/444 [==============================] - 133s 291ms/step - loss: 0.0493 - table_loss: 0.0165 - column_loss: 0.0328 - table_sc_accuracy: 0.9910 - column_sc_accuracy: 0.9818 - val_loss: 0.5992 - val_table_loss: 0.3606 - val_column_loss: 0.2386 - val_table_sc_accuracy: 0.9415 - val_column_sc_accuracy: 0.9318
#
# Epoch 00185: val_loss did not improve from 0.36941
# Epoch 186/200
# 444/444 [==============================] - 133s 291ms/step - loss: 0.0448 - table_loss: 0.0161 - column_loss: 0.0287 - table_sc_accuracy: 0.9910 - column_sc_accuracy: 0.9837 - val_loss: 0.6329 - val_table_loss: 0.3796 - val_column_loss: 0.2533 - val_table_sc_accuracy: 0.9436 - val_column_sc_accuracy: 0.9336
#
# Epoch 00186: val_loss did not improve from 0.36941
# Epoch 187/200
# 444/444 [==============================] - 133s 291ms/step - loss: 0.0433 - table_loss: 0.0154 - column_loss: 0.0279 - table_sc_accuracy: 0.9911 - column_sc_accuracy: 0.9839 - val_loss: 0.6551 - val_table_loss: 0.3955 - val_column_loss: 0.2597 - val_table_sc_accuracy: 0.9419 - val_column_sc_accuracy: 0.9324
#
# Epoch 00187: val_loss did not improve from 0.36941
# Epoch 188/200
# 444/444 [==============================] - 133s 291ms/step - loss: 0.0429 - table_loss: 0.0155 - column_loss: 0.0274 - table_sc_accuracy: 0.9909 - column_sc_accuracy: 0.9838 - val_loss: 0.6888 - val_table_loss: 0.4109 - val_column_loss: 0.2779 - val_table_sc_accuracy: 0.9424 - val_column_sc_accuracy: 0.9319
#
# Epoch 00188: val_loss did not improve from 0.36941
# Epoch 189/200
# 444/444 [==============================] - 133s 291ms/step - loss: 0.0420 - table_loss: 0.0149 - column_loss: 0.0271 - table_sc_accuracy: 0.9914 - column_sc_accuracy: 0.9839 - val_loss: 0.7005 - val_table_loss: 0.4155 - val_column_loss: 0.2850 - val_table_sc_accuracy: 0.9420 - val_column_sc_accuracy: 0.9316
#
# Epoch 00189: val_loss did not improve from 0.36941
# Epoch 190/200
# 444/444 [==============================] - 133s 291ms/step - loss: 0.0428 - table_loss: 0.0154 - column_loss: 0.0275 - table_sc_accuracy: 0.9911 - column_sc_accuracy: 0.9839 - val_loss: 0.6586 - val_table_loss: 0.3918 - val_column_loss: 0.2668 - val_table_sc_accuracy: 0.9420 - val_column_sc_accuracy: 0.9321
#
# Epoch 00190: val_loss did not improve from 0.36941
# Epoch 191/200
# 444/444 [==============================] - 133s 291ms/step - loss: 0.0439 - table_loss: 0.0151 - column_loss: 0.0288 - table_sc_accuracy: 0.9911 - column_sc_accuracy: 0.9832 - val_loss: 0.6689 - val_table_loss: 0.3937 - val_column_loss: 0.2752 - val_table_sc_accuracy: 0.9418 - val_column_sc_accuracy: 0.9303
#
# Epoch 00191: val_loss did not improve from 0.36941
# Epoch 192/200
# 444/444 [==============================] - 133s 290ms/step - loss: 0.0436 - table_loss: 0.0154 - column_loss: 0.0282 - table_sc_accuracy: 0.9911 - column_sc_accuracy: 0.9836 - val_loss: 0.6617 - val_table_loss: 0.4021 - val_column_loss: 0.2596 - val_table_sc_accuracy: 0.9420 - val_column_sc_accuracy: 0.9338
#
# Epoch 00192: val_loss did not improve from 0.36941
# Epoch 193/200
# 444/444 [==============================] - 133s 291ms/step - loss: 0.0423 - table_loss: 0.0145 - column_loss: 0.0278 - table_sc_accuracy: 0.9915 - column_sc_accuracy: 0.9838 - val_loss: 0.6491 - val_table_loss: 0.3851 - val_column_loss: 0.2640 - val_table_sc_accuracy: 0.9408 - val_column_sc_accuracy: 0.9311
#
# Epoch 00193: val_loss did not improve from 0.36941
# Epoch 194/200
# 444/444 [==============================] - 133s 291ms/step - loss: 0.0500 - table_loss: 0.0191 - column_loss: 0.0309 - table_sc_accuracy: 0.9898 - column_sc_accuracy: 0.9827 - val_loss: 0.5115 - val_table_loss: 0.3068 - val_column_loss: 0.2048 - val_table_sc_accuracy: 0.9382 - val_column_sc_accuracy: 0.9292
#
# Epoch 00194: val_loss did not improve from 0.36941
# Epoch 195/200
# 444/444 [==============================] - 133s 291ms/step - loss: 0.0745 - table_loss: 0.0298 - column_loss: 0.0447 - table_sc_accuracy: 0.9865 - column_sc_accuracy: 0.9777 - val_loss: 0.5183 - val_table_loss: 0.2808 - val_column_loss: 0.2375 - val_table_sc_accuracy: 0.9395 - val_column_sc_accuracy: 0.9289
#
# Epoch 00195: val_loss did not improve from 0.36941
# Epoch 196/200
# 444/444 [==============================] - 133s 291ms/step - loss: 0.0643 - table_loss: 0.0249 - column_loss: 0.0393 - table_sc_accuracy: 0.9887 - column_sc_accuracy: 0.9798 - val_loss: 0.5920 - val_table_loss: 0.3446 - val_column_loss: 0.2475 - val_table_sc_accuracy: 0.9380 - val_column_sc_accuracy: 0.9307
#
# Epoch 00196: val_loss did not improve from 0.36941
# Epoch 197/200
# 444/444 [==============================] - 134s 291ms/step - loss: 0.0505 - table_loss: 0.0179 - column_loss: 0.0326 - table_sc_accuracy: 0.9905 - column_sc_accuracy: 0.9818 - val_loss: 0.6057 - val_table_loss: 0.3523 - val_column_loss: 0.2534 - val_table_sc_accuracy: 0.9392 - val_column_sc_accuracy: 0.9315
#
# Epoch 00197: val_loss did not improve from 0.36941
# Epoch 198/200
# 444/444 [==============================] - 133s 291ms/step - loss: 0.0438 - table_loss: 0.0157 - column_loss: 0.0281 - table_sc_accuracy: 0.9910 - column_sc_accuracy: 0.9839 - val_loss: 0.6702 - val_table_loss: 0.3863 - val_column_loss: 0.2838 - val_table_sc_accuracy: 0.9392 - val_column_sc_accuracy: 0.9305
#
# Epoch 00198: val_loss did not improve from 0.36941
# Epoch 199/200
# 444/444 [==============================] - 133s 291ms/step - loss: 0.0422 - table_loss: 0.0154 - column_loss: 0.0268 - table_sc_accuracy: 0.9910 - column_sc_accuracy: 0.9842 - val_loss: 0.6655 - val_table_loss: 0.3755 - val_column_loss: 0.2900 - val_table_sc_accuracy: 0.9434 - val_column_sc_accuracy: 0.9322
#
# Epoch 00199: val_loss did not improve from 0.36941
# Epoch 200/200
# 444/444 [==============================] - 133s 291ms/step - loss: 0.0400 - table_loss: 0.0148 - column_loss: 0.0252 - table_sc_accuracy: 0.9914 - column_sc_accuracy: 0.9849 - val_loss: 0.6219 - val_table_loss: 0.3384 - val_column_loss: 0.2835 - val_table_sc_accuracy: 0.9451 - val_column_sc_accuracy: 0.9338
#
# Epoch 00200: val_loss did not improve from 0.36941

# %% [markdown]
# ## 3. Extracting table
#
# In this section we will use our trained model to segment the table area and apply OCR on the segmented region to finally obtain the table in the given image.

# %%
# loading trained model
model = build_tablenet()
latest_cp = tf.train.latest_checkpoint(checkpoint_dir)
model.load_weights(latest_cp)

# %%
def extract_table(image_fname):
    image_orig = Image.open(image_fname)
    original_dim = image_orig.size
    image = image_orig.resize((512,512))
    np_image = np.asarray(image)/255.0
    tab_mask, _ = model.predict(np.expand_dims(np_image, axis=0))
    
    tab_mask = np.squeeze(render(tab_mask).numpy())

    tab_mask = Image.fromarray(np.uint8(tab_mask))
    tab_mask = tab_mask.resize(original_dim)

    tab_mask = np.array(tab_mask)

    kernel_erode = np.ones((20,20), np.uint8)
    kernel = np.ones((50,50), np.uint8)
    
    tab_mask =cv2.erode(tab_mask, kernel_erode, iterations=2)


    tab_mask = cv2.morphologyEx(tab_mask, cv2.MORPH_OPEN, kernel)
    tab_mask = cv2.morphologyEx(tab_mask, cv2.MORPH_CLOSE, kernel)

    image_orig = np.array(image_orig)
    masked = cv2.bitwise_and(image_orig, image_orig, mask=tab_mask)
    # Ref: https://stackoverflow.com/questions/62813546/how-do-i-crop-an-image-based-on-custom-mask-in-python
    # transparent cropp
    tmp = cv2.cvtColor(masked, cv2.COLOR_BGR2GRAY)
    _,alpha = cv2.threshold(tmp,0,255,cv2.THRESH_BINARY)
    b, g, r = cv2.split(masked)
    rgba = [b,g,r, alpha]
    masked = cv2.merge(rgba,4)
    text = pytesseract.image_to_string(masked)
    print(text)
    plt.figure(figsize=(15,20))
    plt.axis('off')
    plt.imshow(masked)
    plt.show()

# %% [markdown]
# ### Testing on a sample datapoint from ICDAR 2017

# %%
images = os.listdir(os.path.join('data', 'ICDAR 2017', 'table_images'))
r = np.random.randint(len(images))
img_fname = os.path.join('data', 'ICDAR 2017', 'table_images', images[r])
print(img_fname)
extract_table(img_fname)
# Out:
# data\ICDAR 2017\table_images\POD_0090.png
#
#
#
#
#
#
#
#
#
#
#
#
# ee ee wee
# 34 0.5 2.20 0.16 B12 0.08
# 35 0.5 8 a 8 8
# 3.6 0.5 2.20 O16 O12 2.08
# M7 0.5 2.49 0.32 O24 B16
# 35 2.6 817 0.12 8.18 0.07
# 25 a7 0.29 0.23 B17 O11
# OS 28 0.38 0.30 0.22 15
# 35 09 2.44 0.36 O27 0.18
# 5 10 0.58 0.49 0.38 0.20

# %% [markdown]
# ### Discussions
#
# * From the example above we can see that the area segmented by the model does not give a proper rectangular table.
# * It might be due to lack of considerable amount of training data.
# * Resizing the image to higher resolution could have improved performance, but this idea has been discarded due to low resource constraint
# * Text detection by the OCR module is not very precise. It can be improved if we could somehow make the text more distinguisable by applying image operations.
# * Moreover, if the tabular region was segmented properly, the text in proximity to the table borders could be predicted better.
#
# <br>
# <br>
# <hr>
